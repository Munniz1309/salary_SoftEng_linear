# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestRegressor

# %%
# Reading the data
df = pd.read_csv('/content/Software Engineer Salaries.csv')

# %%
# Displaying the DataFrame
df.head()
# Out:
#                          Company  Company Score  \
# 0                       ViewSoft            4.8
# 1                        Workiva            4.3
# 2     Garmin International, Inc.            3.9
# 3                       Snapchat            3.5
# 4  Vitesco Technologies Group AG            3.1
#
#                                            Job Title         Location Date  \
# 0                                  Software Engineer     Manassas, VA   8d
# 1                          Software Support Engineer           Remote   2d
# 2                               C# Software Engineer         Cary, NC   2d
# 3  Software Engineer, Fullstack, 1+ Years of Expe...  Los Angeles, CA   2d
# 4                                  Software Engineer       Seguin, TX   2d
#
#                           Salary
# 0   $68K - $94K (Glassdoor est.)
# 1   $61K - $104K (Employer est.)
# 2  $95K - $118K (Glassdoor est.)
# 3   $97K - $145K (Employer est.)
# 4  $85K - $108K (Glassdoor est.)

# %%
# Displaying information about the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 870 entries, 0 to 869
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company        868 non-null    object
#  1   Company Score  789 non-null    float64
#  2   Job Title      870 non-null    object
#  3   Location       857 non-null    object
#  4   Date           870 non-null    object
#  5   Salary         764 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 40.9+ KB

# %%
# Displaying descriptive statistics of the DataFrame
df.describe()
# Out:
#        Company Score
# count     789.000000
# mean        3.895311
# std         0.524952
# min         1.000000
# 25%         3.600000
# 50%         3.900000
# 75%         4.200000
# max         5.000000

# %%
# Displaying the unique values of each column individually
for i in df.columns:
  print(i)
  print(df[i].unique())
  print('\n')
# Out:
# Company
# ['ViewSoft' 'Workiva' 'Garmin International, Inc.' 'Snapchat'
#  'Vitesco Technologies Group AG' 'Spotify' 'Infor' 'Amerisoft Corporation'
#  'WHOOP' 'PFF' 'Salesforce' 'HealthMine Services, Inc.' 'Honeywell'
#  'Legrand AV' 'Athenahealth' 'Amex' 'SOFT LABS NA' 'Hertz' 'Megaport'
#  '7-Eleven, Inc.' 'Summit Technologies, Inc.' 'Adobe'
#  'The MITRE Corporation' "Boston Children's Hospital" 'Ahold Delhaize USA'
#  'Artera Technologies' 'Samsung Electronics' 'IPG Photonics' 'Crafty'
#  'Crunchyroll, LLC' 'LEGO' 'Principal Financial Group' 'INTEL' 'Hasbro'
#  'Software Engineering Institute' 'University of Dayton' 'MIT'
#  'Amazon.com Services LLC' 'DaqScribe Solutions'
#  'West Virginia University' 'McKesson' 'Noblis' 'eimagine'
#  'CSL SOFTWARE SOLUTIONS' 'Chewy' 'ERPA' 'Afterpay' 'Harvard University'
#  'Brooks Automation' 'DLRdmv' 'Movius Interactive Corporation'
#  'State Street' 'Sonalysts, Inc.' 'Preco, LLC' 'HealthStream' 'Aptiv plc'
#  'Zipongo' 'Snowflake' 'Staffed4U' 'Honeycomb.io' 'Topaz Labs'
#  'WEG Electric Corp' 'Brown and Caldwell' 'Vertafore'
#  'Aerodyne Industries, LLC' 'KAIROS Inc' 'S3' 'J. Paul Getty Trust, The'
#  'Rover.com' 'University of Oregon' 'dōTERRA International'
#  'AHU Technologies' 'ALSTOM' 'Jack Henry & Associates' 'ISPA Technology'
#  'Universal Health Services, Inc. - Corporate Office' 'Relias'
#  'Tickrs Clearing' 'CTC Group' 'GoTab Inc' 'ILOGIC INC' 'CSX'
#  'Synergy ECP' 'M&T Bank' 'Cardlytics' 'Stefanini, Inc'
#  'Innovative Systems' 'Parabola' 'Vibrint' 'Millennium Management'
#  'Sagitec' 'Careerus Soultions' 'Innovien Solutions'
#  'Ocean Power Technologies Inc' 'Riverside Research Institute'
#  'Uber Freight' 'Diverse Career Solutions' 'Likewize' 'MassMutual Ascend'
#  'Washington DC government' 'AnaVation' '3R Info'
#  'Strategic Mission Elements' 'IPSecure, Inc.' 'RELX' 'Solventum'
#  'Focus Technology Solutions Inc' 'Two Six Technologies' 'Adams, Inc.'
#  'CPS Insurance Services' 'Cephas' 'Chubb' 'Consumers Energy'
#  'U.S. Bank National Association' 'MedImpact Healthcare Systems'
#  'IMC Financial Markets' 'Truveta' 'Signature Science, LLC'
#  'JYG Innovations' 'Vensit' 'Independent Software' 'Visionist, Inc.' 'NCR'
#  'Clearwater Analytics' 'Technical Intelligence Solutions, LLC'
#  'CVS Health' 'Delta Defense, LLC' 'Koalafi' 'No.Inc' 'f5'
#  'Arcadia Science' 'Artint Knowledge Tech' 'Castellum Inc' 'Instacart'
#  'WALGREENS' 'Duquesne Light' 'Super Micro Computer' 'UCare'
#  'CyberCore Technologies' 'CoinFlip' 'BI Labs' 'Sahbi Systems'
#  'Cultura Technologies Inc' 'Excelacom' 'Cityblock Health'
#  'Rocket Software' 'Huntington Ingalls Industries Inc.'
#  'Intuitive Machines LLC' 'Equifax' 'Akamai' 'Mailprotector'
#  'Blockit Now Inc' 'TENICA and Associates LLC' 'Arch Capital Group Ltd.'
#  'Lynker Corporation' 'YouTube' 'Perforce Software' 'World Vision USA'
#  'Featurespace' 'Bigbear.ai' 'Benistar Administrative Services, Inc.'
#  'State of Colorado Job Opportunities' 'Intellisource Colorado LLC'
#  'First Command Financial Services, Inc.' 'NBCUniversal'
#  'Thompson Gray Inc.' 'Origence' 'Medius' 'CNH Industrial'
#  'Fusion Plus Solutions Inc.' 'University of Florida'
#  'Northwestern Mutual' 'Hubbell Incorporated' 'Valkyrie Enterprises'
#  'Decision Six' 'Microsoft' 'Ateliere Creative Technologies' 'OpenAI'
#  'Splunk' 'Sasken' 'RealmOne' 'The Wolf Works LLC' 'Aflac, Incorporated'
#  'RingCentral' 'Dallas Area Rapid Transit' 'W R Systems' 'CARECRAFT, INC'
#  'SpecialT Tech' 'Hottinger, Bruel & Kjaer' 'CPS Solutions, LLC'
#  'Northwestern Memorial Healthcare' 'The Swift Group'
#  'ASUS Computer International' 'Persistent Systems' 'Cedar Inc'
#  'Nautilus Hyosung America Inc' 'Blue Origin'
#  'West Bend Insurance Company' 'JBT Corporation'
#  'Allied Business Consulting' 'Chick-fil-A, Inc.'
#  'US AMR-Jones Lang LaSalle Americas, Inc.' 'Smart IMS' 'PayPal'
#  'Hewlett Packard' 'New River Systems Corporation'
#  'Modern Technology Solutions, Inc.' 'PQSecure Technologies' 'OnMed'
#  'Grote Industries' 'Cloud Software Group'
#  'NationMind Infoservices Pvt Ltd' 'Arrowstreet Capital' 'Favorited'
#  'Strategic Thermal Labs' 'IdolSoft' 'Verily' 'Colonial Pipeline Company'
#  'Leader Communications Inc' 'CliftonLarsonAllen' 'BAE Systems'
#  'Nodal Exchange' 'Gomez & Companies' 'T-Mobile USA, Inc.'
#  'Pressco Technology' 'Scentsy Inc' 'STRATASCORP'
#  'Toyota Research Institute' 'Gelber Group' 'PeopleTec, Inc.' 'Flysoft'
#  'Ingrain Systems Inc.' 'Carrier' 'Soar Technology' 'Red Ventures'
#  'Messenger, LLC' 'Nelnet' 'Slate Magazine' 'Airgas' 'Umbra' 'Uber'
#  'Collaborative Robotics' 'Werfen' 'Canon Medical Research USA, Inc'
#  'Raytheon' 'Hudson River Trading' 'Whisker' 'Mastercard'
#  'Savannah River Mission Completion' 'Mill-Max'
#  'Disney Entertainment & ESPN Technology' 'Coca-Cola' 'Kaleido'
#  'Lufburrow & Co' 'Boost Tech' 'VANTACA' 'Numerica Corporation'
#  'Veracity Engineering' 'AppLovin' 'Northwest Talent Solutions LLC'
#  'Honda Research Institute USA' 'Activision' 'thatgamecompany'
#  'BNY Mellon' 'Recruiting From Scratch' 'Akina, Inc.' 'Vonnen' 'Capgemini'
#  'Infosys' 'Link, LLC' 'Autodesk' 'BCT LLC' 'JPMorgan Chase & Co'
#  'WR Systems' 'Acuity Brands' 'Cisco Systems' 'Vivint, Inc.'
#  'Caelum Research Corporation' 'Oracle' 'Fidelity Investments'
#  'Colorado State University' 'Bayer' 'USAA' 'Accenture Federal Services'
#  'Gundersen Health System' 'JRC Integrated Systems, LLC' 'XL Softek'
#  'kasmo cloud solutions' 'ICR, Inc.' 'Workday' '360care'
#  'DKW Communications' 'SICK, Inc.' 'Antithesis' 'Rekuten Global' 'Tencent'
#  'Zoox' 'Innovative Defense Technologies (IDT)'
#  'VETERANS ENGINEERING INCORPORATED' 'Solvere Technical Group'
#  'IRALOGIX,Inc' 'Nava' 'GE HEALTHCARE' 'TC Energy' 'Schlumberger'
#  'IXL Learning' 'FLASH Technology Group' 'Fairfax County Public Schools'
#  'Scholarly' 'Burst Inc.' 'USN Technical Associates' 'SNC'
#  'Laiba Technologies' 'Teamups' 'Delta Dental Ins.' 'UiPath'
#  'Atlas Copco Tools & Assembly Systems LLC' 'ANB Sourcing LLC'
#  'McIntire Solutions' 'Pennymac' 'Literati'
#  'Rochester Software Associates, Inc.' 'Plaid' 'TigerGraph' 'Resilio Inc.'
#  'Candid' 'Radiance Technologies' 'Fabletics' 'Fractal Analytics'
#  'Microchip Technology' 'York Space Systems' 'Proteus Co.'
#  'Software Productivity Strategists' 'NeuroPace' 'OceanFrogs'
#  'iconectiv, LLC.' 'The Aerospace Corporation' 'Fetch Package'
#  'Zenith Services' 'Matthews International Corporation' 'NVIDIA'
#  'PingWind' 'Versaterm' 'Apollo Technology Solutions LLC'
#  'Navrit Creation' 'Schneider Electric' 'Akira Technologies Inc.'
#  'Space Coast Intelligent Solutions' 'Credo' '9th networks Inc' 'Tuvoli'
#  'Walter P Moore' 'LinQuest Corporation' 'CodeSignal'
#  'Dupli Envelope & Graphics' 'Coinbase'
#  'LSEG (London Stock Exchange Group)' 'Inabia Software & Consulting Inc.'
#  'PMall' 'Alloy' 'QinetiQ US' 'Caterpillar' 'Jason Pharmaceuticals, Inc.'
#  'IntelliBridge LLC' 'Snyk' 'Vertex Professional Service LLC'
#  'deciBel Research, Inc.' 'COMSOL Inc.' 'Hero Facility Services'
#  'QED Systems LLC' 'Kasasa' 'Delta Air Lines, Inc.' 'HAN IT'
#  'Innovative Solutions and Support' 'Promega'
#  'Revenue Management Solutions Llc' 'Astrion' 'Broadridge'
#  'Zurn Elkay Water Solutions' 'Florida State College at Jacksonville'
#  'Q9Software' 'The Bank of New York Mellon Corporation'
#  'Grand Canyon Education' 'Captivation Software' 'DocuSign'
#  'Canon Medical Research USA, Inc.' 'Standard Bots' 'American AgCredit'
#  'KAPSCH' 'Prevail' 'DCS Corp' 'Consensus Health' 'Rippling'
#  'ACI Worldwide' 'Engineering Technology Associates, Inc.'
#  'Fusion Innovation' 'Clarity Innovations, LLC'
#  'RippleMatch Opportunities' 'Power3 Solutions and Partnering Companies'
#  'Datadog' 'PACCAR' 'Front' 'Northrop Grumman' 'Pegasystems'
#  'Lawrence Berkeley National Laboratory' 'Cargill' 'GLOBALFOUNDRIES'
#  'TRU47' 'Gopuff' 'Camelot Integrated Solutions Inc.' 'BOEING' 'Publix'
#  'Experian' 'ByteDance' 'Alterra Mountain Company'
#  'Amazon Advertising LLC' 'Bose' 'Macy’s' 'DraftKings' 'GE Appliances'
#  'Quantum Systems Inc' 'Kaseware, Inc.' 'Fanatics Inc.' 'Accrete.AI'
#  'Roku' 'Early Warning Services' 'Grainger' 'Costco Wholesale'
#  'Mochi Health' 'Jacobs' 'Boeing Intelligence & Analytics' 'NetApp'
#  'Alphataraxia' 'Johns Hopkins University' 'University of Vermont'
#  'Federal Reserve Bank of Dallas' 'Grammarly, Inc.'
#  'SCD Information Technology' 'Clarity Innovations' 'Volvo Group'
#  'Calspan Corporation' 'Root//Source' 'HireIO, Inc.' 'PAC GROUP LLC'
#  'Emergent Software' 'Intone Networks' 'CARTIKTECH LLC'
#  'Abbott Laboratories' 'Prove' 'Schweitzer Engineering Laboratories'
#  'Themis Insight' 'Hop Labs' 'Hawaiian Airlines, Inc.' 'Visa'
#  'Oliver Wyman Group' 'Morgan Stanley' 'Multi State Lottery Association'
#  'EOG Resources' 'BAXTER' 'Geon Technologies' 'TDI Technologies'
#  'DAIKIN COMFORT TECHNOLOGIES MFG LP' 'Wise' 'Nyla Technology Solutions'
#  'Wellington Management' 'Vizient, Inc.' 'Leidos' 'ELEVI Associates'
#  'ASCENDING' 'Trellint' 'Lockheed Martin' 'Trusted Space, Inc.'
#  'Availity, LLC.' 'BorgWarner' 'Ford Motor Company' 'Forterra' 'Epsilon'
#  'Logistics Management Institute' 'Sirius XM' 'Warner Bros. Discovery'
#  'Peloton' 'Corteva' 'IntraFi Network' 'PSEG' 'Ryzlink DBA Chuwa America'
#  'Trane Technologies' 'Discord' 'Tesla'
#  'First American Financial Corporation' 'Collins Aerospace' 'Roche'
#  'Qualtrics' 'Edward Rose & Sons' 'Michelin' 'Wipro' 'Harley-Davidson'
#  'VIZIO, Inc.' 'Geneva Technologies Inc.' 'ElectronX' 'Sabre Engineering'
#  'Thermoflow' 'Twitch Interactive, Inc.' 'Adtran' 'Oncorre'
#  'NMG Technology Services' 'Invisible Technologies' 'Metas Solutions'
#  'GAP Solutions, Inc.' 'InterImage' 'Tickets.com' 'Embecta'
#  'Space Systems Integration' 'Cash App' 'Annapurna Labs (U.S.) Inc.'
#  'Index Engines Inc.' 'Squarespace' 'Advanced Micro Devices, Inc'
#  'Flow Systems, Inc' 'Teradyne' 'Meta' 'Yellow Duck Technologies Inc.'
#  'Ops Tech Alliance' 'CDK Global' 'IAB Solutions LLC' 'General Assembly'
#  'Cotiviti' "Braum's" 'Cummings Aerospace Inc' 'T.M. Bier & Associates'
#  'Zelis' 'TikTok' 'Eaton' 'Boston Consulting Group' 'Sage' 'Neurable'
#  'ASM International' 'Galvion' 'Prophet Software' 'Ansira'
#  'Elder Research' '3 Reasons Consulting' 'AB2 Consulting, Inc.'
#  'University of Maryland' 'CPI Card Group' 'Simplot'
#  'Walmart Advanced Systems and Robotics'
#  'NORC at the University of Chicago' 'WSSC Water' 'RVO Health'
#  'Wisenbaker Builder Services' 'Optum' 'SoFi' 'Micron' 'Boeing'
#  'bellelynn' 'Bertrandt' 'EAI Technologies' 'Mahlet' 'REV Robotics'
#  'IntelliGenesis, LLC' 'Enersys' 'University of Washington' 'CEDENT'
#  'Bank of America' 'Federal Reserve Bank of Boston' 'Apriva' 'ASEC'
#  'T. Rowe Price' 'S&S Activewear LLC' 'Peterson Technologies'
#  'LongPath Technologies, Inc.' 'Gradient' 'ENVISN INCORPORATED'
#  'Intersoft Data Labs' 'Digital Insight Printing'
#  'Beshenich Muir & Associates Llc' 'Powermind Solutions' 'ShipperHQ'
#  'Bryn Neil' 'Amazon Web Services, Inc.' 'Bio-Rad Laboratories, Inc.'
#  'Audacy, Inc.' 'CyberKorp' 'NCR Atleos' 'Electronic Warfare Associates'
#  'BillGO, Inc.' 'Genesys' 'January Technologies' 'Zebra Technologies'
#  'Credit One Bank' 'Foot Locker' 'LegalZoom' 'Red Hat, Inc.' 'Turn5, Inc.'
#  'University of Nebraska Medical Center' 'Ren Global Inc.' 'Disney'
#  'AVA Counsulting' 'Cubesmart' 'SimpliSafe' 'Inspire Brands' 'FINSYNC'
#  'Deluxe Media' 'Liquibase' 'Apple' 'Kasmo Inc'
#  'Systems Technology & Research Inc.' 'Timescale' 'Home Care Pulse Llc'
#  'Chatsworth Products' 'KLA Corporation' 'FICO' 'ETC'
#  'CapSquare Systems, Inc.' 'bioMerieux SA' 'Amazon Data Services, Inc.'
#  'DarkStar Intelligence LLC' '10ZIG TECHNOLOGY, INC.' 'Ekeo Group, LLC'
#  'AXS' 'Coupang' 'Verve, Inc.' 'ARSIEM' 'Freeform' 'Aspen Publishing'
#  'Finish Line' 'UBS' 'Paycom'
#  'Patriot Technology and Business Partners, Inc.'
#  'TRU Simulation + Training, Inc.' 'Cart.com' 'RealWork Labs'
#  'Vision Technologies, Inc' 'Thermo Fisher Scientific' 'Atrium Health'
#  'PacBio' 'Marquis Software Solutions Inc' 'Semper Valens Solutions'
#  'Alcorn State University' 'Amazon Web Services, Inc. - A97' 'Reevo'
#  'Teledyne Technologies Inc.' 'Honda' 'Westchester Community College'
#  'DPS Telecom' 'Roblox' 'RXO' 'Medtronic' nan]
#
#
# Company Score
# [4.8 4.3 3.9 3.5 3.1 4.  5.  3.3 4.2 4.1 3.8 3.7 3.2 3.4 2.9 4.4 4.5 2.
#  3.  3.6 4.6 4.7 2.6 2.7 4.9 2.4 2.3 2.5 2.8 1.  nan]
#
#
# Job Title
# ['Software Engineer' 'Software Support Engineer' 'C# Software Engineer'
#  'Software Engineer, Fullstack, 1+ Years of Experience'
#  'Backend Engineer II' 'Associate Software Engineer' 'Software Developers'
#  'Software Engineer II (Backend, Health)' 'Sr. Software Engineer'
#  'MTS Software Engineer' 'Software Engineer I'
#  'Software Engineer, athenaCollector – RCM Rules' 'Java Engineer'
#  'Entry Level to Senior Level Software Developers'
#  'Software Engineer, C++' 'Frontend Software Engineer'
#  'Software Development Engineer' 'Software Engineer - HA (Hybrid)'
#  'Engineer - React/JavaScript' 'Software Engineer - Martech'
#  'Software Engineers' 'Senior Software Engineer'
#  'Software Engineer III, Payments' 'Backend Software Engineer'
#  'Experienced Software Engineer' 'Security Software Engineer'
#  'Software Engineer, Unreal Engine' 'Software Developer'
#  'Software Dev Engineer - Computer Science' 'Jr. Software Engineer'
#  'Software Engineer - Libraries' 'Software Engineer (All Levels)'
#  'Software/Database Developer' 'Software Engineer II'
#  'Software Test Engineer' 'Software Engineer, Incentive'
#  'Software Engineer- Frontend' 'Junior Software Engineer'
#  'Software Engineer - Epic Integrations' 'Software Engineer - Snowpark'
#  'Software Engineer (Level 0 - Level II)'
#  'Midlevel Site Reliability Engineer' 'Software Engineer, Infrastructure'
#  'Software Engineer - Wind' 'Simulation Software Engineer (ADV00095I)'
#  'Senior Software Engineer - Photo AI' 'Software Engineer- 826245'
#  'Software Engineer Sr' 'Software Engineer - ML Performance / HPC'
#  'Senior Software Engineer, Orders Team' 'Research Software Engineer'
#  'Software Release Engineer' 'Junior Software Systems Engineer'
#  'Associate Software Engineer - Data Analytics' 'Jr. Deployment Engineer'
#  'SOFTWARE DEVELOPERS' 'Software Engineer II - Service Now'
#  'Software Engineer III' 'AWS Cloud Engineer' 'C Software Engineer'
#  'Software Engineer, Full Stack' 'Software Engineer I (Python Developer)'
#  'Front End Engineer' 'DevOps Engineer' 'Java Software Engineer'
#  'Software Engineer - Database Engineering' 'Jr DevOps Engineer'
#  'Senior Software Engineer II' 'React Developer'
#  'Software Developer (TypeScript/JavaScript)'
#  'Software Engineer - Front-end (Solventum)' 'Cloud Engineer'
#  'Junior Software Developer' 'Software Engineer - Java Springboot (DT)'
#  'Software Engineer III - Mobile (Multiple Openings)'
#  'Assoc Software Engineer' 'Software Engineer IV'
#  'Graduate Software Engineer' 'Software Engineer - Normalization'
#  'Web Developers' 'Software Engineer - Apprentice'
#  'Software Dev Ops Engineer II' 'Senior Software Development Engineer'
#  'Associate Software Development Engineer - Colleague Experience'
#  'Associate Engineer, Analytics' 'AI Research Engineer'
#  'Software Engineer, Product' 'Firmware (Linux) Dev I'
#  'Senior Software Engineer, Core Experiences' 'Software Engineer (RxR)'
#  'Software Engineer Senior â€“ Azure' 'Software Engineer 0'
#  'AWS DevOps Engineer' 'SOFTWARE DEVELOPERS (021)' 'Sr Software Engineer'
#  'Machine Learning Software Engineer' 'Software Engineer (Hybrid) - 19943'
#  'Software Engineer - Career' 'Software Engineer - Remote'
#  'Elixir Software Engineer' 'Software Systems Engineer TS/SCI CI poly'
#  'Senior Software Engineer, Full Stack, YouTube'
#  'Senior Software Engineer - US'
#  'Cloud Engineer (Remote from anywhere in Colorado)'
#  'Senior Software Engineer - Enterprise People Technology'
#  'Post Software Engineer' 'Cloud Software Engineers' 'Engineer (Software)'
#  'Software Engineer - CUDL Modernization' 'Principal Software Engineer'
#  'Software Engineer I/II' 'Sr Assoc Software Engineer'
#  'Junior Computer/Software Engineer (Job ID: 3433)'
#  'Senior DevOps Engineer - Los Angeles'
#  'Software Engineer, Hardware Health'
#  'Software Engineer (US Remote Available)' 'Node JS'
#  'Software Engineer - C#' 'Software Engineer-BI' 'Cloud Engineer Manager'
#  'Software Engineer - AI' 'Workday Software Engineer'
#  'Software Engineer II (Communications Platform)'
#  'Software Engineering MTS' 'Software Developer - C#, .NET'
#  'Embedded Flight Software Engineer – New Glenn' 'Software Engineer C#'
#  'Software Engineer III (Payment Workflows)'
#  'Senior Software Engineer - Backend Development' 'Software Engineering'
#  'Software Engineer, Backend' 'SharePoint Software Systems Engineer'
#  'Software Engineer - Associate' 'Hardware/Software Engineer'
#  'Mid to Senior Level Software Engineer' 'Site Reliability Engineer'
#  'Networks - Embedded Software Engineer'
#  'Senior Software Engineer (Full-Stack, Java, JavaScript)'
#  'Fullstack Software Engineer' 'Full Stack Engineer' 'SOFTWARE DEVELOPER'
#  'SOFTWARE DEVELOPERS (834)' 'Software Engineer, Enterprise Frontend'
#  'Software Engineer Sr. â€” Net'
#  'Software Engineer Associate Manager - National General'
#  'Software Engineer (Expert)' 'Software Engineer (Mid-level)'
#  'Full Stack Software Engineer & API Developer'
#  'Sr Software Engineer - Data'
#  'API Services - Senior Software Engineer - Java, Spring Boot'
#  'Software Integration & Test Engineer'
#  'Staff Software Engineer, Machine Learning, YouTube Music'
#  'Mid-Level Software Systems Engineer' 'Software Engineer in Testing'
#  'Software Engineer- Executions Team' 'SOFTWARE ENGINEER'
#  'Software Engineer IV - Java Fullstack'
#  'Mid-Level Software Engineer – HYBRID!' 'Autonomy Software Engineer'
#  'Software Engineer | The Points Guy' 'Software Development ITAM Engineer'
#  'IT Software Engineer- NBS' 'Firmware Engineer'
#  'Software Engineer II - Uber Eats' 'Software Engineer, Robotics'
#  'Software Development Engineer in Test, Digital Solutions'
#  'C++ Graphics Engineer, 1+ Years of Experience'
#  'Software Engineer, C++, 3+ Years of Experience'
#  'Systems Software Engineer' 'SoftWare Engineer II'
#  'Associate Software Developer' 'SOFTWARE ENGINEER TRAINEE'
#  'Staff Software Engineer' 'Software Engineer - API, Java, Spring Boot'
#  'Software Engineer - Hybrid' 'Senior Software Engineer (CRM)'
#  'Test Software Engineer' 'Mobile Engineer'
#  'Software Engineer (multiple openings)'
#  'Software Engineer II, C++ Backend'
#  'Junior Software Developer (Java & Azure Cloud)' 'Software Engineer 2'
#  'Software Engineer for Mobile Robots' 'Build Engineer'
#  'Vice President, Back-End Engineer I' 'Founding Software Engineer'
#  'Software Engineer - 1 (Kubernetes/Python)' 'Software Engineer - Redis'
#  'Release Engineer'
#  'Golang Software Engineer (VISTA BIGHITTER), BS+7, Telework'
#  'Software Development Engineer, Platform Services'
#  'Software Engineer (ID)' 'Software QA Engineer'
#  'Application Programmer Analyst/Developer I'
#  'Senior React/Javascript Software Engineer'
#  'Software Engineer | Front End Developer'
#  'Software Engineer - Front End (Dashboard) - Aurora, CO'
#  'Sr Associate Software Engineer, Database as a Service'
#  'Senior Engineer - Java - GO2 Unify' 'Junior Ruby on Rails Engineer'
#  'Security Software Engineer I' 'Software Engineer 1'
#  'Software Engineer, Workflow Orchestration' 'Software Engineer 3'
#  'Backend Python Software Engineer' 'Engineer, Junior Software'
#  'Senior Software Engineer (Hybrid, Onsite)'
#  'New Engineer-in-Training (NET) Rotational Program'
#  'Sr Software Engineer, Snowflake focus' 'Back End Software Engineer'
#  'Software Engineer (One Year Only)' 'DevSecOps Software Engineer'
#  'Video Software Engineer' 'Contract Software Engineer'
#  'DO178C Software Engineer' 'Expert Software Engineer'
#  'Software Engineer (Job ID:3425)'
#  'Azure DevOps Engineer || Full time job.'
#  'Software Systems Engineer/DevOps Engineer' 'Clojure Software Engineer'
#  'WordPress Full Stack Engineer (React)' 'C# Software Developer'
#  'Experienced Software Engineer - Scaled Access'
#  'Software Certification Engineer 1 - Software Quality'
#  'Technical Support Engineer (Endpoint Software)'
#  'Ecosystems Software Engineer' 'Engineer' 'R&D Software Engineer'
#  'Engineer II - Software' 'Sr. Full Stack Software Engineer'
#  'Full Stack Software Engineer' 'Full Stack Software Developer'
#  'Software Engineer (Oracle Database Expertise)'
#  'Data Engineer / Software Engineer' 'Lead Front-End Software Engineer'
#  'React Native Engineer'
#  'Senior Full-Stack Web Applications Software Engineer'
#  'Software Developer*' 'Sr. Front End Engineer (React)'
#  'Freelance Web Developer' 'Software Dev Engineer, Modeling Software'
#  'Systems Application Engineer II - Software'
#  'ServiceNow Software Engineer' 'Python Developer'
#  'System Software Engineer' 'Go Lang/Platform Engineer'
#  'Front-end Software Developer' 'Software Engineer, Innovation Lab'
#  'Software Quality Engineer' 'Front-End Developer' 'Solutions Engineer'
#  'Senior Software Engineer (Typescript/Go)'
#  'Software Engineer II (inSITE) - "W-TRS"' 'Mid-Level Software Engineer'
#  'Full Stack Engineer, Leverage Engineering'
#  'Software Developer – Ray Optics' 'Junior Python Developer'
#  'Entry Level Developer' 'Senior Software Engineer (Hybrid)'
#  'Software Verification Engineer' 'Software Engineer, Instrumentation'
#  'Software Systems Engineer - Mason, OH' 'Deployment Engineer (Hybrid)'
#  'IoT Engineer' 'Engineer IV Software'
#  '2025 BNY Summer Internship Program - Engineering (Developer)'
#  'Jr. Developer' 'Software Engineer 0 - Java/React/Docker/AWS'
#  'AI SaaS Engineer' 'Software Engineer Video'
#  'Full Stack Engineer II (Frontend) - Benefits'
#  'Jr. Java Software Engineer (SWE1) (PP) 228'
#  'IMC - Software Engineer, application via RippleMatch' 'Python Engineer'
#  'Senior Software Engineer - Frontend - Sheets'
#  'Vehicle Software and Diagnostics Tool Test Engineer'
#  'Backend Software Engineer, Deliverability'
#  '2024 Associate Software Engineer - Linthicum MD'
#  'Associate Software Engineer, Services Engineering'
#  'Optimization Software Engineer'
#  'Associate Software Engineer - Technology Development Program, Summer 2025 - Atlanta, GA'
#  'Software Engineer - Perception ML Ops'
#  'Design Enablement Engineer, Software Engineering AI/Machine Learning (2024 New College Graduate)'
#  'Shopify Webmaster'
#  'Software Development Test Engineer - Electrical IoT Devices'
#  'Senior Software Engineer - Delivery Tech'
#  'Senior Software Engineer - Warehouse' 'Senior Software Engineer I'
#  'Software Engineer - Enterprise Identity Services'
#  'Software Engineer - Junior Level'
#  'Software Engineer – Customer Payments Support'
#  'Staff Software Engineer (Remote)'
#  'Senior Frontend Software Engineer - Customer Service Plateform - Seattle'
#  'Software Engineer, Mobile (React Native)'
#  'Senior Software Engineer (Remote)'
#  'Junior Software Engineer (SWE1) (QC) TTO16-022'
#  'Software Quality Assurance Engineer (Level 6), Automotive'
#  'Front End/UI Mid-Level Software Engineer' 'DSP Software Engineer'
#  'Lead Software Engineer - Supply Chain' 'Senior Software Engineer, IOS'
#  'Software Engineering Co-op_Summer 2025'
#  'Software Engineer II - Automated Reasoning and Testing'
#  'Sr Software Development Engineer' 'Senior Software Engineer C++'
#  'Software Engineer II, (Java/AWS)' 'Engineer I-Software'
#  'Software Engineer III, Android'
#  'Machine Learning Engineer (Early Career)'
#  'Senior Software Engineer, Service Mesh'
#  'Software Engineer - Java, Zelle' 'Front-End Engineer - Content Platform'
#  'Software Engineer IV (Success Factors - Employee Central Payroll)'
#  'Software Engineer - Digital Data Products'
#  'Senior Software Engineer, Frontend' 'Entry Level Software Engineer'
#  'Software Engineer - C/C++'
#  'Entry Level Support Equipment Software Engineer'
#  'Software Engineer II - .Net, C#, Azure'
#  'Senior Software Engineer - Courier Pricing'
#  'Software Quality Assurance Engineer, Assistance Vice President'
#  'Embedded Software Engineer'
#  'Software Engineering/Electrical Engineering Co-op - Fall 2024 (US Persons)'
#  'Software Engineer, Data Engineering'
#  'Software Engineer - Level 1 (RR) RRTN-8319'
#  'Software Engineer - 3 (JavaScript/Go/Python)'
#  'Co-Op: Software (Spring 2025)'
#  'Associate Software Engineer, Edwards Air Force Base'
#  'Software Engineer - Rider Support Tools'
#  'Senior Software Engineer - Aviation Databases'
#  'Full Stack Java Software Engineer (hybrid)'
#  'Software and Systems Engineer' 'Sr Software Engineer (Back-end)'
#  'Software Engineer (Python)' 'Sr. Software Engineer, HBS Online'
#  'Software Development Engineer in Test'
#  'Senior Software Engineer, Orchestration Team'
#  'Associate Software Engineer - C# Emphasis'
#  'Jr. Software Engineer - Hybrid/Remote'
#  'Software Development Engineer III' 'Staff Software Engineer - Documents'
#  'ML Software Engineer'
#  'Software Developer Engineer, IT Technical Operations'
#  'Software Engineer Lead' 'Full-Stack Software Engineer – LMTS / PMTS'
#  'Software Engineer – Senior Consultant Level - Tink'
#  'NERA Associate Software Engineer'
#  'System Software Engineer – Autonomous Vehicles Platform'
#  'Associate, Python / Perl Dev'
#  'Backend Software Engineer, Digital Banking-Payments'
#  'Senior Backend Software Engineer (Hybrid)'
#  'Software Engineer - PubSub, Cash App'
#  'Software Engineer 2 - Mainframe (Cobol, JCL, VSAM)'
#  'Software Engineer / Simulation - Virtual Prototyping'
#  'SOFTWARE ENGINEER 3' 'Software Engineer in Test' 'Jr Cloud Engineer'
#  'Senior Software Engineer II, Wise Account'
#  'Senior .NET Software Engineer' 'Software Engineer - IT Sustainability'
#  'Junior Software Engineer - Panama Shift!'
#  'Software Solutions Engineer – Multiple Levels' 'Cloud Software Engineer'
#  'R&D Software Engineer II'
#  'Software Development Engineer, Officer, Onsite'
#  'Node.js/Kotlin Software Engineer IV' 'Software Resident Engineer'
#  'Perception Software Engineer - ML Ops'
#  'Senior Front End Software Engineer'
#  'Software Engineer (Data Security-US) - 2025 Start (BS/MS)'
#  'Custom Software Engineer'
#  'Senior Software Engineer - Python, Celery, Redis'
#  'VP, Software Engineering' 'Software Engineer- Backend'
#  'Software Programmer' 'Software Engineer - Innovation'
#  'Software Engineer, Ads (Quests)'
#  'Staff Software Engineer, Backend, Factory Software'
#  'Software Engineer II (Hybrid or Remote Possible)'
#  'Software Engineer (Customer-Facing Applications)'
#  'Senior Software Engineer - Digital Pathology'
#  'Senior Software Development Engineer - Data Engineering Team'
#  'Yardi Enterprise Software Support Engineer - Hybrid Remote'
#  'Software Engineer(Entry/Experienced) SPA'
#  'Embedded C / Linux Software Engineer - Marine' 'PHP Engineer'
#  'Associate Design Engineer - Software V&V'
#  'Experienced: Core Infrastructure Software Engineer'
#  'Software Developer (Job Code 001)' 'JR. SOFTWARE ENGINEER'
#  'Computer Science, Software Engineers, Programmers'
#  'Software Engineer 2 - DevOps' 'Senior Software Engineer - Platform'
#  'Software Quality Assurance Engineer & Tester'
#  'Software QA Engineer and Tester' 'Software Integration Engineer, Junior'
#  '2251 Java & NiFi Software Engineer'
#  'Senior FullStack Software Engineer (hybrid - Andover, MA)'
#  'Sr. Software Engineer, Backend, Factory Software'
#  'Full-Stack Software Developer'
#  'Software Dev Engineer - Machine Learning Apps, Accelerator'
#  'React Software Engineer'
#  'Senior Software Engineer, User Platform (Java)'
#  'Software Development Engineer - AI/ML'
#  '2128 Software Engineer 1 (Java Focused)'
#  'Senior Software Engineer, Search Evaluations'
#  'Software Performance Engineer'
#  'Software Engineer - Camera (Technical Leadership)'
#  'Cleared Junior Software Engineer' 'Software Engineer Level 3'
#  'Software Engineer Instructor' 'Sr. DevOps Engineer'
#  'Software Engineer - Mid Level' 'Software Engineer-Mid Level'
#  'Software Engineer (BMS)' 'Senior Software Engineer - C# & Rust'
#  'Frontend Software Engineer Graduate, TikTok Infrastructure - 2025 Start (BS/MS)'
#  'Eaton Development Program: Engineering Technology - Software'
#  'Senior Fullstack Software Engineer - Perception Metrics Platform'
#  'AI Software Engineer, Campus, United States - BCG X'
#  'Software Engineer - C#, C++' 'Field Software Support Engineer'
#  'Associate Software Engineer (on-site)'
#  'Software Development Engineer in Test (SDET) / Okemos, MI (Hybrid)'
#  'Research Software and Data Engineer' 'Software Process Engineer'
#  'Senior Software Engineer – Emulation' 'Software Engineer II, Android'
#  'Engineering Software Administrator (e-Builder, Primavera P6)'
#  '2025 Early Career Program: Software Engineering'
#  'CAD Software Engineer (Cabinets)'
#  'Senior AI/ML Software Engineer, Java - Remote'
#  'Staff Software Engineer, At Work' 'IT Software Engineer'
#  'Software Engineer 3 - Front End (contract)'
#  'Automotive Software Engineer'
#  'Front End Engineer, Sponsored Brands - Fixed'
#  'Software Engineering LMTS' 'Software Engineer - Global Order Bank'
#  'Physics/Math Graduate - Entry Level Software Developer'
#  'OneStream Software Systems Engineer' 'SENIOR SOFTWARE ENGINEER'
#  'Full Stack Software Engineer Level 1' 'Product Engineer I'
#  'Cloud Software Development Engineer' 'Software Engineer - Backend Voice'
#  'Software System Engineer (C++, JAVA background)'
#  'Ground Software Engineer' 'Experienced Front-End Engineer'
#  'Full-Stack Software Engineer – Digital Money and Payments Research & Development'
#  'Software Engineering Co-op (Summer/Fall 2025) (Onsite)'
#  'Senior Software Engineer (Hybrid Available)'
#  'Mid Level Software Engineer'
#  'Software Development Engineer II, Sort Tech'
#  'Software Quality Assurance (Tester) Engineer'
#  'Software Engineer (Onsite)' 'Magento Developer'
#  'Software Machine Learning Engineer' 'Software Systems Engineer'
#  'Software Engineer - Credit' 'Software Engineer, Back-End'
#  'Sr. Software Engineer - Site Reliability' 'Cleared Software Engineer'
#  'Data Center Services - Software Engineer'
#  'Software Dev Engineer, L5 , SFSC Integrations'
#  'Software Developer in Test'
#  'Software Developers – Multiple openings – Bloomingdale, IL'
#  'Junior Java Software Engineer' 'Apprentice ETL Software Engineer'
#  'Software Engineer, Tool & Infrastructure, Reliability & Test'
#  'Software Engineer, Engineering Acceleration'
#  'ATM Software Engineer (Level III)'
#  'JavaScript Software Engineer – Analytics UI Team'
#  'Software Engineer, Borrower Activation'
#  'DevSecOps Software Engineer, II' 'Sr. SW Engineer'
#  'Lead Software Engineer, Integrations (Boomi)'
#  'Senior Software Engineer, iOS' 'Software Integration Engineer'
#  'Trainee Automation Engineer' 'Full Stack Software Engineer - Mid-Level'
#  'Software Engineer, Tools GPU (Core)' 'Software Engineer - Applied AI'
#  'Automated Driving Software Engineer'
#  'Software Development Engineer, DevOps (US Federal)'
#  'Senior Software Engineer, ML Ops' 'Senior Software Engineer (Ruby)'
#  'Software Engineer, Gameplay - Reality Labs'
#  'Site Reliability Engineer (Remote, US-based)'
#  'AIML - Software Engineer, Information Intelligence'
#  'Software Engineer III, Machine Learning (Recommendations, Rankings, and Predictions), YouTube'
#  'PLC Software Engineer'
#  'Senior Software Engineer - Backend - AI Projects'
#  '2172 Software Engineer 1' 'Database Software Engineer'
#  'Sr. Software Engineer – Full Stack'
#  'PLATFORM ENGINEER II/ Software Engineer'
#  'GPU/Accelerator Packaging Software Engineer'
#  'Senior Software Engineer, Infrastructure - Platform (Routing)'
#  'Senior Full Stack Software Engineer'
#  'Software application developer - Officer (Onsite)'
#  'Software Engineer (C++/OOD/OOP, Linux, Multi-Thread/Multi-Process)'
#  'Senior Java Engineer' 'Android Engineer, Music'
#  'Software Engineer - Entertainment Controls'
#  'Software Engineer II - Cybersecurity and OS Configuration'
#  'Software Development Engineer, Network Core-R&D'
#  'Senior Software Engineer in Test' 'QA Automation Engineer'
#  'Analytics Engineer' 'Senior Software QA Engineer'
#  '568 Software Engineer 0' 'Software Engineer (C++)'
#  'Software Engineer - Wind Tunnels & Hypersonics'
#  'Software Development Analyst'
#  'Senior Software Engineer - Enterprise Solutions'
#  'Software Engineer/Developer' 'Software Applications Engineer'
#  'Senior Full Stack Software Engineer, Code Builder/IDE'
#  'Software Engineer (Full Stack) (QC) TTO16-002'
#  'Aerospace App Software Engineer II'
#  'Software Engineer (Aerodynamics) - TRU Simulation Training, Inc.'
#  'IO Software Systems Test Engineer' 'Deployment Engineer'
#  'Software Quality Assurance Engineer III'
#  'Software Engineer - ML Infrastructure' 'ServiceNow Sr Software Engineer'
#  'Principal Software Engineer - Full Stack'
#  'Software Engineer (Associate or Experienced)'
#  'Senior Engineer, Software, Test' 'SR SOFTWARE ENGINEER'
#  'Lead Software Engineer'
#  'Senior Software QA Engineer Apple Sevices Engineering.'
#  'Principal Software Development Engineer' 'Software Engineer/Instructor'
#  'Software Dev Engineer II, AWS Applications'
#  'Software & System Dev. Sr. Engineer'
#  'Embedded Software Engineer (Entry-Level)'
#  'Senior Software Engineer - App Orchestration'
#  'Software Engineer, Machine Learning Compute'
#  'Software Engineer - 3 (Apache NiFi)'
#  'GUI Software Engineer II - Surgical Robotics']
#
#
# Location
# ['Manassas, VA' 'Remote' 'Cary, NC' 'Los Angeles, CA' 'Seguin, TX'
#  'New York, NY' 'Alpharetta, GA' 'Farmington Hills, MI' 'Boston, MA'
#  'San Francisco, CA' 'Aguadilla, PR' 'Minneapolis-Saint Paul'
#  'Plantation, FL' 'Northborough, MA' 'Seattle, WA' nan 'Irving, TX'
#  'Springfield, MA' 'San Jose, CA' 'Bedford, MA' 'Sunrise, FL'
#  'Carlisle, PA' 'Annapolis Junction, MD' 'Lehi, UT' 'Mountain View, CA'
#  'Oxford, MA' 'Chicago, IL' 'Irvine, CA' 'Des Moines, IA' 'Phoenix, AZ'
#  'Renton, WA' 'Pittsburgh, PA' 'Dayton, OH' 'Cambridge, MA'
#  'United States' 'Morgantown, WV' 'Chantilly, VA' 'Burlington, VT'
#  'Bellevue, WA' 'Dublin, OH' 'Fremont, CA' 'Dallas, TX' 'Burlington, MA'
#  'Waterford, CT' 'Somerset, WI' 'Nashville, TN' 'Troy, MI' 'Barre, VT'
#  'Atlanta, GA' 'Melville, NY' 'Kennedy Sp Ct, FL' 'Dahlgren, VA'
#  'Stennis Space Center, MS' 'Eugene, OR' 'Utah' 'Newark, DE'
#  'Washington, DC' 'King of Prussia, PA' 'Morrisville, NC' 'Fort Meade, MD'
#  'Arlington, VA' 'Township of Hamilton' 'Jacksonville, FL'
#  'Wilmington, DE' 'Menlo Park, CA' 'Richmond, VA' 'Saint Paul, MN'
#  'Fairborn, OH' 'Cincinnati, OH' 'Quantico, VA' 'Canton, MI'
#  'Patrick AFB, FL' 'Georgia' 'Maplewood, MN' 'Warrenton, VA' 'Tennessee'
#  'Melbourne, FL' 'Whitehouse Station, NJ' 'Jackson, MI' 'Hopkins, MN'
#  'San Diego, CA' 'Egg Harbor Township, NJ' 'Frederick, MD'
#  'Sayreville, NJ' 'Indiana' 'Crystal City, VA' 'Woonsocket, RI'
#  'West Bend, WI' 'Arizona' 'Baltimore, MD' 'Berkeley, CA'
#  'Patuxent River, MD' 'Deerfield, IL' 'Minneapolis, MN' 'Plainsboro, NJ'
#  'Alabama' 'Denver, CO' 'New York State' 'Massachusetts' 'Columbia, MD'
#  'Houston, TX' 'McKinney, TX' 'Las Cruces, NM' 'Greensboro, NC' 'Avon, CT'
#  'Colorado' 'Bentonville, AR' 'Englewood Cliffs, NJ' 'Redstone Arsenal'
#  'Edison, NJ' 'Florida' 'Franklin, WI' 'Huntsville, AL' 'Herndon, VA'
#  'Redmond, WA' 'Tysons Corner, VA' 'Austin, TX' 'Belmont, CA'
#  'Carlsbad, CA' 'Pompano Beach, FL' 'Hillsboro, OR' 'Scottsdale, AZ'
#  'Chalfont, PA' 'Somerset, NJ' 'McLean, VA' 'Spring, TX' 'Boca Raton, FL'
#  'Tampa, FL' 'Madison, IN' 'Naperville, IL' 'Santa Monica, CA'
#  'Georgetown, TX' 'San Bruno, CA' 'Hill AFB, UT' 'Canoga Park, CA'
#  'Buffalo, NY' 'Solon, OH' 'Meridian, ID' 'Los Altos, CA' 'Jamesburg, NJ'
#  'Sherman, TX' 'Charlotte, NC' 'Ann Arbor, MI' 'San Juan, PR'
#  'Lansing, MI' 'Auburn, IN' 'Lincoln, NE' 'Cheshire, CT'
#  'Santa Barbara, CA' 'Santa Clara, CA' 'Auburn Hills, MI' 'O Fallon, MO'
#  'Aiken, SC' 'Oyster Bay, NY' 'Raleigh, NC' 'Havre de Grace, MD'
#  'Nashua, NH' 'Fort Collins, CO' 'Palo Alto, CA' 'California'
#  'Lake Mary, FL' 'Dearborn, MI' 'Oregon' 'Jersey City, NJ' 'Conyers, GA'
#  'Redwood City, CA' 'Westlake, TX' 'Indianola, PA' 'San Antonio, TX'
#  'Lorton, VA' 'Onalaska, WI' 'Suwanee, GA' 'Carol Stream, IL' 'Aurora, CO'
#  'Louisville, KY' 'Point Mugu NAWC, CA' 'Vienna, VA' 'Beloit, WI'
#  'Maryland' 'Foster City, CA' 'Fall River, MA' 'Indian Head, MD'
#  'Lexington Park, MD' 'Milwaukee, WI' 'San Mateo, CA' 'Laurel, MD'
#  'Wilton Woods, VA' 'Lexington, MA' 'Southern Pines, NC'
#  'Newtown Square, PA' 'Everett, WA' 'Agoura Hills, CA' 'Texas' 'Salem, OR'
#  'Virginia' 'Oakland, CA' 'Greenwood Village, CO' 'Rockville, MD'
#  'Duluth, GA' 'Bridgewater, NJ' 'Apopka, FL' 'Scott Air Force Base, IL'
#  'Lexington, SC' 'Colony, AL' 'Secaucus, NJ' 'Beavercreek, OH'
#  'Syracuse, NY' 'Burr Ridge, IL' 'Peoria, IL' 'Orlando, FL'
#  'Aberdeen Proving Ground, MD' 'Morris Plains, NJ' 'Exton, PA'
#  'Madison, WI' 'Oklahoma City, OK' 'Eglin AFB, FL' 'Mason, OH'
#  'Newark, NJ' 'Germantown, MD' 'Glen Cove, NY' 'Lenexa, KS' 'Norcross, GA'
#  'Mount Vernon, WA' 'Linthicum, MD' 'Waltham, MA' 'Malta, NY'
#  'Foxborough, MA' 'Miami, FL' 'Hartford, CT' 'Lakeland, FL'
#  'Framingham, MA' 'Johns Creek, GA' 'Moorpark, CA' 'Buffalo Grove, IL'
#  'Mount Laurel, NJ' 'Culver City, CA' 'Boulder, CO' 'Lake Forest, IL'
#  'Kennedy Space Center, FL' 'Quincy, MA' 'Shippensburg, PA'
#  'Edwards AFB, CA' 'Olathe, KS' 'Suffolk, VA' 'Sylmar, CA' 'Pullman, WA'
#  'Honolulu, HI' 'Richardson, TX' 'White Plains, NY' 'Johnston, IA'
#  'Brookfield, WI' 'Pennsylvania' 'Chatsworth, CA' 'Fairfax, VA'
#  'Highlands Ranch, CO' 'Elkridge, MD' 'Bethpage, NY' 'Idaho Falls, ID'
#  'Bloomfield Hills, MI' 'Spartanburg, SC' 'Wauwatosa, WI' 'Monument, CO'
#  'Brooklyn, NY' 'Andover, MA' 'Albuquerque, NM' 'Cupertino, CA'
#  'Berthoud, CO' 'North Reading, MA' 'Whitehall Township' 'Largo, FL'
#  'New Jersey' 'Peachtree City, GA' 'Lawrenceville, GA' 'Portsmouth, NH'
#  'Westlake Village, CA' 'Washington State' 'Fort George G Meade, MD'
#  'Okemos, MI' 'College Park, MD' 'Fort Wayne, IN' 'Boise, ID'
#  'Hillsboro, TX' 'Eden Prairie, MN' 'El Segundo, CA'
#  'Sterling Heights, MI' 'Burtonsville, MD' 'Carrollton, TX' 'Longmont, CO'
#  'Warren, MI' 'Cedar Rapids, IA' 'Owings Mills, MD' 'Bolingbrook, IL'
#  'Hanover, MD' 'Burlingame, CA' 'Tempe, AZ' 'Fort Belvoir, VA' 'Plano, TX'
#  'Hercules, CA' 'Frisco, TX' 'Indianapolis, IN' 'Holtsville, NY'
#  'Las Vegas, NV' 'Glendale, CA' 'Paoli, PA' 'Omaha, NE' 'Ela, NC'
#  'Santa Fe Springs, CA' 'Emeryville, CA' 'Malvern, PA' 'Kennesaw, GA'
#  'Burbank, CA' 'Detroit, MI' 'Alameda, CA' 'Ireland, WV' 'Round Rock, TX'
#  'Milpitas, CA' 'San Rafael, CA' 'Middleton, WI' 'Salt Lake City, UT'
#  'Bloomington, MN' 'Celebration, FL' 'Tewksbury, MA' 'Tukwila, WA'
#  'Belcamp, MD' 'Lorman, MS' 'Elgin, IL' 'Raymond, OH' 'Valhalla, NY'
#  'Lake Hopatcong, NJ' 'Southfield, MI']
#
#
# Date
# ['8d' '2d' '1d' '7d' '30d+' '10d' '5d' '6d' '13d' '3d' '4d' '9d' '22d'
#  '18d' '17d' '16d' '20d' '25d' '12d' '23d' '11d' '19d' '26d' '29d' '24d'
#  '15d' '24h' '27d' '30d' '21d' '14d']
#
#
# Salary
# ['$68K - $94K\xa0(Glassdoor est.)' '$61K - $104K\xa0(Employer est.)'
#  '$95K - $118K\xa0(Glassdoor est.)' '$97K - $145K\xa0(Employer est.)'
#  '$85K - $108K\xa0(Glassdoor est.)' '$123K - $175K\xa0(Employer est.)'
#  '$77K - $94K\xa0(Glassdoor est.)' '$71K - $100K\xa0(Glassdoor est.)'
#  '$94K - $148K\xa0(Glassdoor est.)' '$147K - $189K\xa0(Employer est.)'
#  '$90K - $113K\xa0(Employer est.)' '$54K - $79K\xa0(Glassdoor est.)'
#  '$91K - $135K\xa0(Glassdoor est.)' '$70K - $135K\xa0(Employer est.)'
#  '$192K - $288K\xa0(Employer est.)' '$100K - $125K\xa0(Employer est.)'
#  '$85K - $127K\xa0(Glassdoor est.)' '$69K - $109K\xa0(Glassdoor est.)'
#  '$124K - $234K\xa0(Employer est.)' '$84K - $133K\xa0(Glassdoor est.)'
#  '$85K - $150K\xa0(Employer est.)' '$48K - $89K\xa0(Glassdoor est.)'
#  '$66K - $97K\xa0(Glassdoor est.)' '$108K - $199K\xa0(Employer est.)'
#  '$102K - $173K\xa0(Employer est.)' '$124K - $142K\xa0(Employer est.)'
#  '$94K - $133K\xa0(Glassdoor est.)' '$70K - $116K\xa0(Glassdoor est.)'
#  '$142K - $178K\xa0(Employer est.)' '$87K - $135K\xa0(Employer est.)'
#  '$77K - $182K\xa0(Employer est.)' '$101K - $144K\xa0(Glassdoor est.)'
#  '$101K - $168K\xa0(Employer est.)' '$74K - $118K\xa0(Glassdoor est.)'
#  '$100K - $200K\xa0(Employer est.)' '$51K - $78K\xa0(Glassdoor est.)'
#  '$71K - $237K\xa0(Employer est.)' '$87K - $116K\xa0(Glassdoor est.)'
#  '$116K - $184K\xa0(Employer est.)' '$75K - $103K\xa0(Glassdoor est.)'
#  '$155K - $221K\xa0(Employer est.)' '$112K - $165K\xa0(Employer est.)'
#  '$73K - $109K\xa0(Glassdoor est.)' '$120K - $150K\xa0(Employer est.)'
#  '$88K - $124K\xa0(Glassdoor est.)' '$77K - $87K\xa0(Employer est.)'
#  '$65K - $90K\xa0(Employer est.)' '$74K - $101K\xa0(Glassdoor est.)'
#  '$74K - $111K\xa0(Glassdoor est.)' '$147K - $186K\xa0(Employer est.)'
#  '$129K - $174K\xa0(Glassdoor est.)' '$89K - $125K\xa0(Glassdoor est.)'
#  '$165K - $190K\xa0(Employer est.)' '$110K - $160K\xa0(Employer est.)'
#  '$61K - $110K\xa0(Glassdoor est.)' '$94K - $154K\xa0(Employer est.)'
#  '$75K - $115K\xa0(Employer est.)' '$62K - $106K\xa0(Glassdoor est.)'
#  '$72K - $118K\xa0(Glassdoor est.)' '$75K - $118K\xa0(Glassdoor est.)'
#  '$98K - $137K\xa0(Glassdoor est.)' '$113K - $150K\xa0(Employer est.)'
#  '$110K - $140K\xa0(Employer est.)' '$141K - $179K\xa0(Employer est.)'
#  '$77K - $136K\xa0(Glassdoor est.)' '$80K\xa0(Employer est.)'
#  '$79K - $126K\xa0(Glassdoor est.)' '$87K - $119K\xa0(Glassdoor est.)'
#  '$72K - $94K\xa0(Glassdoor est.)' '$6K - $7K\xa0(Employer est.)'
#  '$68K - $106K\xa0(Glassdoor est.)' '$56K - $88K\xa0(Glassdoor est.)'
#  '$72K - $113K\xa0(Glassdoor est.)' '$90K - $119K\xa0(Glassdoor est.)'
#  '$101K - $135K\xa0(Glassdoor est.)' '$155K - $180K\xa0(Employer est.)'
#  '$85K - $114K\xa0(Glassdoor est.)' '$130K - $160K\xa0(Employer est.)'
#  '$160K - $250K\xa0(Employer est.)' '$100K\xa0(Employer est.)'
#  '$96K - $146K\xa0(Glassdoor est.)' '$107K - $144K\xa0(Glassdoor est.)'
#  '$138K - $189K\xa0(Glassdoor est.)' '$78K - $118K\xa0(Glassdoor est.)'
#  '$113K - $139K\xa0(Glassdoor est.)'
#  '$80.00\xa0Per Hour\xa0(Employer est.)'
#  '$70K - $109K\xa0(Glassdoor est.)' '$73K - $117K\xa0(Glassdoor est.)'
#  '$62K - $107K\xa0(Glassdoor est.)' '$124K - $169K\xa0(Glassdoor est.)'
#  '$96K - $117K\xa0(Employer est.)' '$84K - $140K\xa0(Glassdoor est.)'
#  '$66K - $94K\xa0(Glassdoor est.)' '$70K - $120K\xa0(Employer est.)'
#  '$78K - $126K\xa0(Employer est.)' '$165K - $209K\xa0(Employer est.)'
#  '$90K - $125K\xa0(Glassdoor est.)' '$116K - $150K\xa0(Employer est.)'
#  '$107K - $192K\xa0(Employer est.)' '$79K - $120K\xa0(Glassdoor est.)'
#  '$94K - $153K\xa0(Employer est.)' '$84K - $129K\xa0(Glassdoor est.)'
#  '$48K - $81K\xa0(Glassdoor est.)' '$82K - $129K\xa0(Glassdoor est.)'
#  '$61K - $104K\xa0(Glassdoor est.)' '$182K - $244K\xa0(Employer est.)'
#  '$96K - $116K\xa0(Employer est.)' '$68K - $136K\xa0(Employer est.)'
#  '$93K - $132K\xa0(Glassdoor est.)' '$77K - $125K\xa0(Glassdoor est.)'
#  '$52K - $200K\xa0(Employer est.)' '$81K - $118K\xa0(Glassdoor est.)'
#  '$128K - $192K\xa0(Employer est.)' '$150K - $225K\xa0(Employer est.)'
#  '$50.00\xa0Per Hour\xa0(Employer est.)' '$85K - $120K\xa0(Employer est.)'
#  '$192K - $245K\xa0(Employer est.)' '$114K - $182K\xa0(Employer est.)'
#  '$102K - $134K\xa0(Glassdoor est.)' '$101K - $160K\xa0(Employer est.)'
#  '$90K - $124K\xa0(Glassdoor est.)' '$88K - $128K\xa0(Glassdoor est.)'
#  '$83K - $131K\xa0(Glassdoor est.)' '$70K - $90K\xa0(Employer est.)'
#  '$164K - $182K\xa0(Employer est.)' '$73K - $92K\xa0(Employer est.)'
#  '$108K - $200K\xa0(Employer est.)' '$123K - $160K\xa0(Glassdoor est.)'
#  '$112K - $141K\xa0(Glassdoor est.)' '$69K - $143K\xa0(Employer est.)'
#  '$120K - $140K\xa0(Employer est.)' '$68K - $120K\xa0(Glassdoor est.)'
#  '$104K - $136K\xa0(Glassdoor est.)' '$82K - $115K\xa0(Glassdoor est.)'
#  '$161K - $239K\xa0(Employer est.)' '$107K - $150K\xa0(Employer est.)'
#  '$91K - $122K\xa0(Glassdoor est.)' '$103K - $144K\xa0(Glassdoor est.)'
#  '$80K - $100K\xa0(Employer est.)' '$100K - $128K\xa0(Employer est.)'
#  '$90K - $180K\xa0(Employer est.)' '$110K - $130K\xa0(Employer est.)'
#  '$76K - $121K\xa0(Glassdoor est.)' '$88K - $111K\xa0(Employer est.)'
#  '$73K - $116K\xa0(Glassdoor est.)' '$182K - $273K\xa0(Employer est.)'
#  '$85K - $113K\xa0(Glassdoor est.)' '$65K - $95K\xa0(Employer est.)'
#  '$109K - $168K\xa0(Employer est.)' '$80K - $99K\xa0(Glassdoor est.)'
#  '$104K - $153K\xa0(Glassdoor est.)' '$78K - $129K\xa0(Glassdoor est.)'
#  '$82K - $118K\xa0(Glassdoor est.)' '$138K - $294K\xa0(Employer est.)'
#  '$136K - $187K\xa0(Glassdoor est.)' '$295K - $440K\xa0(Employer est.)'
#  '$95K - $146K\xa0(Glassdoor est.)' '$117K - $161K\xa0(Employer est.)'
#  '$173K\xa0(Employer est.)' '$175K - $250K\xa0(Employer est.)'
#  '$55K - $140K\xa0(Employer est.)' '$126K - $234K\xa0(Employer est.)'
#  '$78K - $129K\xa0(Employer est.)' '$75K - $102K\xa0(Glassdoor est.)'
#  '$115K - $150K\xa0(Employer est.)' '$115K - $160K\xa0(Employer est.)'
#  '$82K - $92K\xa0(Employer est.)' '$120K - $130K\xa0(Employer est.)'
#  '$86K - $131K\xa0(Glassdoor est.)' '$92K - $133K\xa0(Glassdoor est.)'
#  '$112K - $165K\xa0(Glassdoor est.)'
#  '$50.00 - $70.00\xa0Per Hour\xa0(Employer est.)'
#  '$145K - $162K\xa0(Employer est.)' '$72K - $159K\xa0(Employer est.)'
#  '$79K - $111K\xa0(Glassdoor est.)' '$115K - $161K\xa0(Employer est.)'
#  '$82K - $102K\xa0(Employer est.)' '$86K - $136K\xa0(Glassdoor est.)'
#  '$170K - $200K\xa0(Employer est.)' '$90K - $116K\xa0(Glassdoor est.)'
#  '$114K - $152K\xa0(Glassdoor est.)' '$80K - $120K\xa0(Employer est.)'
#  '$95K - $126K\xa0(Glassdoor est.)' '$138K - $178K\xa0(Employer est.)'
#  '$61K - $147K\xa0(Employer est.)' '$124K - $211K\xa0(Employer est.)'
#  '$90K - $117K\xa0(Glassdoor est.)' '$98K - $209K\xa0(Employer est.)'
#  '$78K - $121K\xa0(Glassdoor est.)' '$100K - $165K\xa0(Employer est.)'
#  '$125K\xa0(Employer est.)' '$71K - $112K\xa0(Glassdoor est.)'
#  '$95K - $152K\xa0(Employer est.)' '$86K - $105K\xa0(Glassdoor est.)'
#  '$135K - $216K\xa0(Employer est.)' '$93K - $112K\xa0(Employer est.)'
#  '$104K - $161K\xa0(Glassdoor est.)' '$77K - $121K\xa0(Glassdoor est.)'
#  '$95K - $134K\xa0(Glassdoor est.)' '$125K - $178K\xa0(Employer est.)'
#  '$76K - $108K\xa0(Glassdoor est.)' '$77K - $116K\xa0(Glassdoor est.)'
#  '$82K - $106K\xa0(Glassdoor est.)' '$86K - $120K\xa0(Glassdoor est.)'
#  '$96K - $146K\xa0(Employer est.)' '$96K - $137K\xa0(Glassdoor est.)'
#  '$141K - $239K\xa0(Employer est.)' '$108K - $140K\xa0(Employer est.)'
#  '$40.00 - $55.00\xa0Per Hour\xa0(Employer est.)'
#  '$108K - $195K\xa0(Employer est.)' '$111K - $184K\xa0(Employer est.)'
#  '$189K - $284K\xa0(Employer est.)' '$79K - $109K\xa0(Glassdoor est.)'
#  '$94K - $129K\xa0(Glassdoor est.)' '$56K - $83K\xa0(Glassdoor est.)'
#  '$202K - $290K\xa0(Employer est.)' '$70K - $103K\xa0(Glassdoor est.)'
#  '$86K - $121K\xa0(Glassdoor est.)' '$74K - $107K\xa0(Glassdoor est.)'
#  '$81K - $113K\xa0(Glassdoor est.)' '$72K - $119K\xa0(Glassdoor est.)'
#  '$80K - $150K\xa0(Employer est.)' '$72K - $144K\xa0(Employer est.)'
#  '$70K - $95K\xa0(Employer est.)' '$100K - $140K\xa0(Employer est.)'
#  '$88K - $119K\xa0(Glassdoor est.)' '$123K - $198K\xa0(Employer est.)'
#  '$158K - $176K\xa0(Employer est.)' '$160K - $180K\xa0(Employer est.)'
#  '$89K - $139K\xa0(Glassdoor est.)' '$53K - $103K\xa0(Employer est.)'
#  '$129K - $228K\xa0(Employer est.)' '$150K - $250K\xa0(Employer est.)'
#  '$116K - $163K\xa0(Glassdoor est.)' '$104K - $127K\xa0(Glassdoor est.)'
#  '$53K - $96K\xa0(Employer est.)' '$60K - $90K\xa0(Employer est.)'
#  '$143K - $191K\xa0(Employer est.)' '$142K - $162K\xa0(Employer est.)'
#  '$89K - $129K\xa0(Glassdoor est.)' '$94K - $156K\xa0(Employer est.)'
#  '$80K - $148K\xa0(Glassdoor est.)' '$62K - $105K\xa0(Employer est.)'
#  '$81K - $164K\xa0(Employer est.)' '$98K - $145K\xa0(Glassdoor est.)'
#  '$157K - $207K\xa0(Employer est.)' '$133K - $143K\xa0(Employer est.)'
#  '$79K - $159K\xa0(Employer est.)' '$132K - $190K\xa0(Glassdoor est.)'
#  '$90K - $143K\xa0(Glassdoor est.)' '$101K - $187K\xa0(Employer est.)'
#  '$58K - $103K\xa0(Glassdoor est.)' '$125K - $200K\xa0(Employer est.)'
#  '$168K\xa0(Employer est.)' '$110K - $143K\xa0(Glassdoor est.)'
#  '$80.00 - $85.00\xa0Per Hour\xa0(Employer est.)'
#  '$78K - $112K\xa0(Glassdoor est.)' '$95K - $125K\xa0(Glassdoor est.)'
#  '$92K - $158K\xa0(Employer est.)' '$147K - $180K\xa0(Employer est.)'
#  '$60K - $112K\xa0(Employer est.)' '$108K - $151K\xa0(Glassdoor est.)'
#  '$123K - $196K\xa0(Employer est.)' '$116K - $166K\xa0(Glassdoor est.)'
#  '$59K - $107K\xa0(Glassdoor est.)' '$104K - $163K\xa0(Glassdoor est.)'
#  '$68K - $80K\xa0(Employer est.)' '$83K - $107K\xa0(Glassdoor est.)'
#  '$109K - $209K\xa0(Employer est.)' '$97K - $197K\xa0(Employer est.)'
#  '$57K - $96K\xa0(Glassdoor est.)' '$66K - $90K\xa0(Glassdoor est.)'
#  '$55.00 - $60.00\xa0Per Hour\xa0(Employer est.)'
#  '$79K - $168K\xa0(Employer est.)' '$102K - $174K\xa0(Employer est.)'
#  '$73K - $108K\xa0(Glassdoor est.)' '$110K - $190K\xa0(Employer est.)'
#  '$94K - $137K\xa0(Glassdoor est.)' '$89K - $113K\xa0(Glassdoor est.)'
#  '$128K - $179K\xa0(Glassdoor est.)' '$74K - $125K\xa0(Glassdoor est.)'
#  '$90K - $187K\xa0(Employer est.)' '$143K - $256K\xa0(Employer est.)'
#  '$114K - $145K\xa0(Glassdoor est.)' '$101K - $155K\xa0(Glassdoor est.)'
#  '$84K - $128K\xa0(Glassdoor est.)'
#  '$100.00\xa0Per Hour\xa0(Employer est.)'
#  '$71K - $104K\xa0(Glassdoor est.)' '$99K - $137K\xa0(Glassdoor est.)'
#  '$15.69\xa0Per Hour\xa0(Employer est.)'
#  '$141K - $211K\xa0(Employer est.)' '$76K - $128K\xa0(Employer est.)'
#  '$93K - $129K\xa0(Glassdoor est.)' '$93K - $131K\xa0(Glassdoor est.)'
#  '$86K - $145K\xa0(Glassdoor est.)' '$67K - $112K\xa0(Glassdoor est.)'
#  '$85K - $115K\xa0(Employer est.)' '$90K - $115K\xa0(Glassdoor est.)'
#  '$92K - $156K\xa0(Employer est.)' '$150K - $200K\xa0(Employer est.)'
#  '$95K - $147K\xa0(Glassdoor est.)' '$102K - $148K\xa0(Glassdoor est.)'
#  '$40.00 - $60.00\xa0Per Hour\xa0(Employer est.)'
#  '$86K - $109K\xa0(Glassdoor est.)' '$87K - $125K\xa0(Glassdoor est.)'
#  '$75.00 - $80.00\xa0Per Hour\xa0(Employer est.)'
#  '$142K - $183K\xa0(Employer est.)' '$162K - $244K\xa0(Employer est.)'
#  '$85K - $104K\xa0(Glassdoor est.)' '$140K - $145K\xa0(Employer est.)'
#  '$95K - $130K\xa0(Glassdoor est.)' '$90K - $150K\xa0(Employer est.)'
#  '$140K - $150K\xa0(Employer est.)' '$183K - $297K\xa0(Employer est.)'
#  '$97K - $129K\xa0(Glassdoor est.)' '$50K - $90K\xa0(Employer est.)'
#  '$74K - $122K\xa0(Employer est.)' '$82K - $114K\xa0(Glassdoor est.)'
#  '$215K - $220K\xa0(Employer est.)' '$75K - $126K\xa0(Glassdoor est.)'
#  '$79K - $119K\xa0(Glassdoor est.)' '$125K - $150K\xa0(Employer est.)'
#  '$77K - $102K\xa0(Glassdoor est.)' '$102K - $138K\xa0(Glassdoor est.)'
#  '$115K - $155K\xa0(Glassdoor est.)' '$84K - $132K\xa0(Glassdoor est.)'
#  '$80K - $108K\xa0(Glassdoor est.)' '$148K - $230K\xa0(Employer est.)'
#  '$81K - $101K\xa0(Glassdoor est.)' '$65K - $112K\xa0(Glassdoor est.)'
#  '$88K - $117K\xa0(Glassdoor est.)' '$10K - $20K\xa0(Employer est.)'
#  '$111K - $153K\xa0(Glassdoor est.)' '$91K - $126K\xa0(Glassdoor est.)'
#  '$125K - $140K\xa0(Employer est.)' '$66K - $116K\xa0(Glassdoor est.)'
#  '$108K - $146K\xa0(Glassdoor est.)' '$90K - $130K\xa0(Employer est.)'
#  '$80K - $90K\xa0(Employer est.)' '$86K - $119K\xa0(Glassdoor est.)'
#  '$120K - $250K\xa0(Employer est.)' '$54K - $83K\xa0(Employer est.)'
#  '$55K - $90K\xa0(Employer est.)' '$84K - $157K\xa0(Employer est.)'
#  '$96K - $128K\xa0(Glassdoor est.)' '$106K - $125K\xa0(Employer est.)'
#  '$81K - $123K\xa0(Glassdoor est.)' '$92K - $131K\xa0(Glassdoor est.)'
#  '$115K - $166K\xa0(Glassdoor est.)' '$113K - $161K\xa0(Glassdoor est.)'
#  '$160K - $385K\xa0(Employer est.)' '$62K - $102K\xa0(Glassdoor est.)'
#  '$73K - $110K\xa0(Glassdoor est.)' '$200K - $370K\xa0(Employer est.)'
#  '$93K - $147K\xa0(Glassdoor est.)' '$69K - $107K\xa0(Glassdoor est.)'
#  '$50K - $60K\xa0(Employer est.)' '$70K - $108K\xa0(Glassdoor est.)'
#  '$103K - $133K\xa0(Glassdoor est.)' '$84K - $110K\xa0(Glassdoor est.)'
#  '$102K - $149K\xa0(Glassdoor est.)' '$187K - $197K\xa0(Employer est.)'
#  '$70K - $96K\xa0(Glassdoor est.)' '$100K - $110K\xa0(Employer est.)'
#  '$83K - $116K\xa0(Glassdoor est.)' '$100K - $250K\xa0(Employer est.)'
#  '$100K - $115K\xa0(Employer est.)' '$64K - $101K\xa0(Glassdoor est.)'
#  '$66K - $68K\xa0(Employer est.)' '$79K - $117K\xa0(Glassdoor est.)'
#  '$140K\xa0(Employer est.)' '$118K - $169K\xa0(Glassdoor est.)'
#  '$56K - $89K\xa0(Glassdoor est.)' '$130K - $270K\xa0(Employer est.)'
#  '$110K - $157K\xa0(Employer est.)' '$93K - $130K\xa0(Glassdoor est.)'
#  '$94K - $160K\xa0(Employer est.)' '$108K - $156K\xa0(Glassdoor est.)'
#  '$74K - $100K\xa0(Glassdoor est.)' '$73K - $100K\xa0(Glassdoor est.)'
#  '$112K - $196K\xa0(Employer est.)' '$80K - $94K\xa0(Employer est.)'
#  '$89K - $130K\xa0(Glassdoor est.)' '$78K - $131K\xa0(Glassdoor est.)'
#  '$65K - $107K\xa0(Glassdoor est.)' '$130K - $300K\xa0(Employer est.)'
#  '$66K - $98K\xa0(Employer est.)' '$153K - $225K\xa0(Employer est.)'
#  '$69K - $103K\xa0(Employer est.)' '$83K - $114K\xa0(Glassdoor est.)'
#  '$107K - $174K\xa0(Employer est.)' '$78K\xa0(Employer est.)'
#  '$175K - $265K\xa0(Employer est.)' '$53K - $107K\xa0(Employer est.)'
#  '$60.00 - $80.00\xa0Per Hour\xa0(Employer est.)'
#  '$86K - $128K\xa0(Glassdoor est.)' '$165K - $215K\xa0(Employer est.)'
#  '$76K - $175K\xa0(Employer est.)' '$96K - $118K\xa0(Employer est.)'
#  '$86K - $129K\xa0(Employer est.)' '$184K - $337K\xa0(Employer est.)'
#  '$127K - $184K\xa0(Employer est.)' '$79K - $130K\xa0(Glassdoor est.)'
#  '$120K - $207K\xa0(Employer est.)' '$112K - $152K\xa0(Employer est.)'
#  '$130K - $158K\xa0(Glassdoor est.)' '$103K - $172K\xa0(Employer est.)'
#  '$82K - $209K\xa0(Employer est.)' '$116K - $174K\xa0(Employer est.)'
#  '$130K - $165K\xa0(Employer est.)' '$150K - $185K\xa0(Employer est.)'
#  '$102K - $204K\xa0(Employer est.)' '$108K - $216K\xa0(Employer est.)'
#  '$79K - $116K\xa0(Glassdoor est.)' '$67K - $128K\xa0(Employer est.)'
#  '$129K - $162K\xa0(Employer est.)' '$90K - $110K\xa0(Employer est.)'
#  '$117K - $306K\xa0(Employer est.)' '$87K - $142K\xa0(Glassdoor est.)'
#  '$92K - $132K\xa0(Glassdoor est.)' '$105K - $160K\xa0(Employer est.)'
#  '$144K - $196K\xa0(Glassdoor est.)' '$69K - $91K\xa0(Glassdoor est.)'
#  '$80K - $110K\xa0(Employer est.)' '$100K - $153K\xa0(Glassdoor est.)'
#  '$87K - $124K\xa0(Glassdoor est.)' '$185K - $206K\xa0(Employer est.)'
#  '$80K - $133K\xa0(Employer est.)' '$90K - $127K\xa0(Glassdoor est.)'
#  '$73K - $127K\xa0(Employer est.)' '$100K - $140K\xa0(Glassdoor est.)'
#  '$160K - $194K\xa0(Employer est.)' '$107K - $145K\xa0(Glassdoor est.)'
#  '$74K - $131K\xa0(Glassdoor est.)' '$240K\xa0(Employer est.)'
#  '$16.00 - $46.00\xa0Per Hour\xa0(Employer est.)'
#  '$160K - $225K\xa0(Employer est.)' '$99K - $134K\xa0(Glassdoor est.)'
#  '$102K - $143K\xa0(Glassdoor est.)' '$150K - $240K\xa0(Employer est.)'
#  '$160K - $170K\xa0(Employer est.)' '$144K - $200K\xa0(Employer est.)'
#  '$110K - $120K\xa0(Employer est.)' '$165K - $211K\xa0(Employer est.)'
#  '$92K - $116K\xa0(Glassdoor est.)'
#  '$65.00\xa0Per Hour\xa0(Employer est.)' '$66K - $132K\xa0(Employer est.)'
#  '$140K - $175K\xa0(Employer est.)' '$169K - $225K\xa0(Employer est.)'
#  '$61K - $95K\xa0(Employer est.)' '$90K - $125K\xa0(Employer est.)'
#  '$162K - $284K\xa0(Employer est.)' '$91K - $137K\xa0(Employer est.)'
#  '$160K - $175K\xa0(Employer est.)' '$177K - $323K\xa0(Employer est.)'
#  '$133K - $193K\xa0(Employer est.)' '$81K - $99K\xa0(Glassdoor est.)'
#  '$85K - $95K\xa0(Employer est.)' '$180K - $339K\xa0(Employer est.)'
#  '$163K - $200K\xa0(Employer est.)' '$93K - $128K\xa0(Glassdoor est.)'
#  '$112K - $154K\xa0(Employer est.)' '$102K - $132K\xa0(Employer est.)'
#  '$80K - $111K\xa0(Glassdoor est.)' '$187K - $280K\xa0(Employer est.)'
#  '$105K - $155K\xa0(Glassdoor est.)' '$92K - $120K\xa0(Glassdoor est.)'
#  '$230K - $280K\xa0(Employer est.)' '$94K - $128K\xa0(Glassdoor est.)'
#  '$129K\xa0(Employer est.)' '$80K - $180K\xa0(Employer est.)'
#  '$105K - $190K\xa0(Employer est.)' '$139K - $169K\xa0(Employer est.)'
#  '$54K - $98K\xa0(Employer est.)' '$55K - $186K\xa0(Employer est.)'
#  '$101K - $139K\xa0(Glassdoor est.)' '$88K - $120K\xa0(Glassdoor est.)'
#  '$129K - $202K\xa0(Employer est.)' '$70K - $115K\xa0(Employer est.)'
#  '$91K - $134K\xa0(Glassdoor est.)' '$92K - $124K\xa0(Glassdoor est.)'
#  '$115K - $190K\xa0(Employer est.)' '$94K - $139K\xa0(Glassdoor est.)'
#  '$140K - $216K\xa0(Glassdoor est.)' '$90K - $103K\xa0(Employer est.)'
#  '$95K - $170K\xa0(Employer est.)' '$343K - $637K\xa0(Employer est.)'
#  '$172K - $223K\xa0(Employer est.)'
#  '$105.00 - $115.00\xa0Per Hour\xa0(Employer est.)'
#  '$93K - $186K\xa0(Employer est.)' '$83K - $110K\xa0(Glassdoor est.)'
#  '$120K\xa0(Employer est.)' '$88K - $140K\xa0(Employer est.)'
#  '$95K - $136K\xa0(Glassdoor est.)' '$100K - $130K\xa0(Employer est.)'
#  '$159K - $175K\xa0(Employer est.)' '$104K - $348K\xa0(Employer est.)'
#  '$78K - $104K\xa0(Employer est.)' '$64K - $128K\xa0(Employer est.)'
#  '$117K - $216K\xa0(Employer est.)' '$135K - $247K\xa0(Employer est.)'
#  '$83K - $136K\xa0(Glassdoor est.)' '$85K - $130K\xa0(Glassdoor est.)'
#  '$99.00\xa0Per Hour\xa0(Employer est.)' '$73K - $88K\xa0(Employer est.)'
#  '$59K - $88K\xa0(Employer est.)' '$105K - $146K\xa0(Glassdoor est.)'
#  '$70K - $125K\xa0(Employer est.)' '$62K - $98K\xa0(Glassdoor est.)'
#  '$82K - $119K\xa0(Glassdoor est.)' '$80K - $113K\xa0(Glassdoor est.)'
#  '$67K - $106K\xa0(Glassdoor est.)' '$129K - $224K\xa0(Employer est.)'
#  '$169K\xa0(Employer est.)'
#  '$45.66 - $54.99\xa0Per Hour\xa0(Employer est.)'
#  '$140K - $180K\xa0(Employer est.)' '$69K - $98K\xa0(Glassdoor est.)'
#  '$59K - $86K\xa0(Glassdoor est.)' '$80K - $123K\xa0(Glassdoor est.)'
#  '$105K - $152K\xa0(Glassdoor est.)' '$135K - $175K\xa0(Employer est.)'
#  '$154K - $279K\xa0(Employer est.)' '$76K - $155K\xa0(Employer est.)'
#  '$99K\xa0(Employer est.)' '$129K - $207K\xa0(Employer est.)'
#  '$161K - $215K\xa0(Glassdoor est.)' '$95K - $115K\xa0(Employer est.)'
#  '$310K - $465K\xa0(Employer est.)' '$117K - $160K\xa0(Glassdoor est.)'
#  '$213K - $293K\xa0(Employer est.)' '$163K - $294K\xa0(Employer est.)'
#  '$195K - $230K\xa0(Employer est.)' '$86K - $109K\xa0(Employer est.)'
#  '$79K - $124K\xa0(Glassdoor est.)' '$122K - $147K\xa0(Employer est.)'
#  '$110K - $154K\xa0(Employer est.)' '$119K - $142K\xa0(Employer est.)'
#  '$85K - $131K\xa0(Glassdoor est.)' '$60K - $80K\xa0(Employer est.)'
#  '$112K - $177K\xa0(Employer est.)' '$90K - $104K\xa0(Employer est.)'
#  '$195K - $245K\xa0(Employer est.)' '$66K - $112K\xa0(Glassdoor est.)'
#  '$145K - $190K\xa0(Employer est.)' '$86K - $127K\xa0(Glassdoor est.)'
#  '$61K - $89K\xa0(Glassdoor est.)' '$68K - $102K\xa0(Glassdoor est.)'
#  '$79K - $125K\xa0(Glassdoor est.)' '$100K - $155K\xa0(Glassdoor est.)'
#  '$94K - $122K\xa0(Glassdoor est.)'
#  '$60.00 - $72.00\xa0Per Hour\xa0(Employer est.)'
#  '$105K - $125K\xa0(Employer est.)' '$103K - $147K\xa0(Glassdoor est.)'
#  '$122K - $172K\xa0(Glassdoor est.)' '$122K - $184K\xa0(Employer est.)'
#  '$121K - $181K\xa0(Employer est.)' '$78K - $133K\xa0(Employer est.)'
#  '$75K\xa0(Employer est.)' '$86K - $139K\xa0(Glassdoor est.)'
#  '$88K - $173K\xa0(Employer est.)' '$182K - $244K\xa0(Glassdoor est.)'
#  '$124K - $155K\xa0(Employer est.)'
#  '$72.84 - $80.93\xa0Per Hour\xa0(Employer est.)'
#  '$65K - $101K\xa0(Glassdoor est.)' '$161K - $243K\xa0(Employer est.)'
#  '$76K - $107K\xa0(Glassdoor est.)' '$70K - $85K\xa0(Employer est.)'
#  '$75K - $150K\xa0(Employer est.)' '$110K - $150K\xa0(Employer est.)'
#  '$98K - $147K\xa0(Glassdoor est.)' '$74K - $92K\xa0(Employer est.)'
#  '$8K - $12K\xa0(Employer est.)' '$90K - $131K\xa0(Employer est.)'
#  '$126K - $237K\xa0(Employer est.)' '$50K - $78K\xa0(Glassdoor est.)'
#  '$94K - $117K\xa0(Glassdoor est.)' '$185K - $200K\xa0(Employer est.)'
#  '$103K - $149K\xa0(Employer est.)' '$109K - $141K\xa0(Glassdoor est.)'
#  '$76K - $116K\xa0(Glassdoor est.)' '$37K - $82K\xa0(Employer est.)'
#  '$129K - $159K\xa0(Glassdoor est.)' '$95K - $133K\xa0(Glassdoor est.)'
#  '$130K - $140K\xa0(Employer est.)' '$180K - $260K\xa0(Employer est.)'
#  '$86K - $111K\xa0(Glassdoor est.)'
#  '$40.00 - $45.00\xa0Per Hour\xa0(Employer est.)'
#  '$74K - $109K\xa0(Glassdoor est.)' '$108K - $116K\xa0(Employer est.)'
#  '$103K - $146K\xa0(Glassdoor est.)' '$89K - $128K\xa0(Glassdoor est.)'
#  '$84K\xa0(Employer est.)' '$144K - $198K\xa0(Employer est.)'
#  '$160K - $321K\xa0(Employer est.)' '$97K - $155K\xa0(Glassdoor est.)'
#  '$120K - $290K\xa0(Employer est.)' '$87K - $126K\xa0(Glassdoor est.)'
#  '$103K - $141K\xa0(Employer est.)' '$135K - $155K\xa0(Employer est.)'
#  '$65K - $118K\xa0(Employer est.)' '$300K - $450K\xa0(Employer est.)'
#  '$90K - $126K\xa0(Glassdoor est.)' '$78K - $102K\xa0(Glassdoor est.)'
#  '$87K - $171K\xa0(Employer est.)' '$125K - $160K\xa0(Employer est.)'
#  '$83K - $124K\xa0(Employer est.)' '$74K - $98K\xa0(Glassdoor est.)'
#  '$102K - $159K\xa0(Employer est.)' '$115K - $165K\xa0(Employer est.)'
#  '$90K - $145K\xa0(Employer est.)' '$68K - $104K\xa0(Glassdoor est.)'
#  '$72K - $108K\xa0(Employer est.)' '$69K - $120K\xa0(Glassdoor est.)'
#  '$72K - $127K\xa0(Glassdoor est.)' '$158K - $205K\xa0(Employer est.)'
#  '$100K - $160K\xa0(Employer est.)'
#  '$50.00 - $54.00\xa0Per Hour\xa0(Employer est.)'
#  '$130K - $210K\xa0(Employer est.)' '$115K - $159K\xa0(Glassdoor est.)'
#  '$138K - $192K\xa0(Glassdoor est.)' '$130K - $150K\xa0(Employer est.)'
#  '$177K - $251K\xa0(Employer est.)' '$100K - $158K\xa0(Glassdoor est.)'
#  '$168K - $253K\xa0(Employer est.)' '$167K - $296K\xa0(Employer est.)'
#  '$136K - $200K\xa0(Employer est.)'
#  '$35.00 - $50.00\xa0Per Hour\xa0(Employer est.)'
#  '$118K - $142K\xa0(Employer est.)' '$109K - $219K\xa0(Employer est.)'
#  '$64K - $113K\xa0(Glassdoor est.)' '$104K - $166K\xa0(Employer est.)'
#  '$181K - $212K\xa0(Employer est.)' '$91K - $119K\xa0(Glassdoor est.)'
#  '$161K - $253K\xa0(Employer est.)' '$90K - $140K\xa0(Employer est.)'
#  '$81K - $131K\xa0(Glassdoor est.)' '$77K - $104K\xa0(Glassdoor est.)'
#  '$125K - $208K\xa0(Employer est.)' '$105K - $130K\xa0(Glassdoor est.)'
#  '$62K - $89K\xa0(Glassdoor est.)' '$110K - $145K\xa0(Employer est.)'
#  '$116K - $128K\xa0(Employer est.)' '$138K - $297K\xa0(Employer est.)'
#  '$109K - $145K\xa0(Glassdoor est.)' '$97K - $133K\xa0(Glassdoor est.)'
#  '$100K - $145K\xa0(Employer est.)' '$86K - $129K\xa0(Glassdoor est.)'
#  '$53K - $96K\xa0(Glassdoor est.)' '$75K - $131K\xa0(Employer est.)'
#  '$119K - $173K\xa0(Glassdoor est.)' '$97K - $126K\xa0(Glassdoor est.)'
#  '$84K - $106K\xa0(Glassdoor est.)' '$81K - $109K\xa0(Glassdoor est.)'
#  '$166K - $228K\xa0(Employer est.)' '$115K - $154K\xa0(Employer est.)'
#  '$66K - $109K\xa0(Glassdoor est.)' '$116K - $204K\xa0(Employer est.)'
#  '$102K - $150K\xa0(Glassdoor est.)' '$139K - $184K\xa0(Glassdoor est.)'
#  '$94K - $118K\xa0(Glassdoor est.)' '$94K - $136K\xa0(Glassdoor est.)'
#  '$126K - $265K\xa0(Employer est.)' '$100K - $135K\xa0(Glassdoor est.)'
#  '$175K - $209K\xa0(Employer est.)' '$248K - $385K\xa0(Employer est.)'
#  '$91K - $152K\xa0(Employer est.)' '$129K - $193K\xa0(Employer est.)'
#  '$98K - $135K\xa0(Glassdoor est.)' '$114K - $149K\xa0(Glassdoor est.)'
#  '$130K - $236K\xa0(Employer est.)' '$144K - $288K\xa0(Employer est.)'
#  '$49K - $84K\xa0(Glassdoor est.)' '$118K - $184K\xa0(Glassdoor est.)'
#  '$86K - $116K\xa0(Glassdoor est.)' '$80K - $119K\xa0(Employer est.)'
#  '$88K\xa0(Employer est.)' '$55K\xa0(Employer est.)'
#  '$234K - $284K\xa0(Employer est.)' '$222K\xa0(Employer est.)'
#  '$95K - $143K\xa0(Employer est.)' nan]

# %%
# Checking the number of missing values in each column
df.isnull().sum()
# Out:
# Company            2
# Company Score     81
# Job Title          0
# Location          13
# Date               0
# Salary           106
# dtype: int64

# %%
# Dropping rows with missing values from the DataFrame
df.dropna(inplace=True)

# %%
# Removing "(Glassdoor est.)" and "(Employer est.)" from the 'Salary'
df['Salary'] = df['Salary'].str.replace(r"\s*\(Glassdoor est.\)", "", regex=True)
df['Salary'] = df['Salary'].str.replace(r"\s*\(Employer est.\)", "", regex=True)

# %%
# Displaying the DataFrame after modifications
df.head()
# Out:
#                          Company  Company Score  \
# 0                       ViewSoft            4.8
# 1                        Workiva            4.3
# 2     Garmin International, Inc.            3.9
# 3                       Snapchat            3.5
# 4  Vitesco Technologies Group AG            3.1
#
#                                            Job Title         Location Date  \
# 0                                  Software Engineer     Manassas, VA   8d
# 1                          Software Support Engineer           Remote   2d
# 2                               C# Software Engineer         Cary, NC   2d
# 3  Software Engineer, Fullstack, 1+ Years of Expe...  Los Angeles, CA   2d
# 4                                  Software Engineer       Seguin, TX   2d
#
#          Salary
# 0   $68K - $94K
# 1  $61K - $104K
# 2  $95K - $118K
# 3  $97K - $145K
# 4  $85K - $108K

# %%
# Using regular expressions to extract minimum and maximum salary values from the 'Salary' column
df[['Min_Salary', 'Max_Salary']] = df['Salary'].str.extract(r'(\$[\dK]+)(?: - )?(\$[\dK]+)?', expand=True)

# Filling missing values in the 'Max_Salary' column with the corresponding values from 'Min_Salary'
df['Max_Salary'] = df['Max_Salary'].fillna(df['Min_Salary'])

# %%
# Displaying the DataFrame after salary extraction
df.head()
# Out:
#                          Company  Company Score  \
# 0                       ViewSoft            4.8
# 1                        Workiva            4.3
# 2     Garmin International, Inc.            3.9
# 3                       Snapchat            3.5
# 4  Vitesco Technologies Group AG            3.1
#
#                                            Job Title         Location Date  \
# 0                                  Software Engineer     Manassas, VA   8d
# 1                          Software Support Engineer           Remote   2d
# 2                               C# Software Engineer         Cary, NC   2d
# 3  Software Engineer, Fullstack, 1+ Years of Expe...  Los Angeles, CA   2d
# 4                                  Software Engineer       Seguin, TX   2d
#
#          Salary Min_Salary Max_Salary
# 0   $68K - $94K       $68K       $94K
# 1  $61K - $104K       $61K      $104K
# 2  $95K - $118K       $95K      $118K
# 3  $97K - $145K       $97K      $145K
# 4  $85K - $108K       $85K      $108K

# %%
# Converting the values to integers
df['Min_Salary'] = df['Min_Salary'].str.replace('$', '').str.replace('K', '000').astype(int)
df['Max_Salary'] = df['Max_Salary'].str.replace('$', '').str.replace('K', '000').astype(int)

# %%
# Displaying descriptive statistics of the updated salary columns
df.describe()
# Out:
#        Company Score     Min_Salary     Max_Salary
# count     753.000000     753.000000     753.000000
# mean        3.895618  101325.706507  150506.317397
# std         0.526348   40745.484788   64919.179969
# min         1.000000      15.000000      15.000000
# 25%         3.600000   79000.000000  115000.000000
# 50%         3.900000   95000.000000  139000.000000
# 75%         4.200000  120000.000000  178000.000000
# max         5.000000  343000.000000  637000.000000

# %%
# Dropping the original 'Salary' column since the salaries have been split into minimum and maximum columns
df.drop('Salary', axis=1, inplace=True)

# Dropping the 'Date' column
df.drop('Date', axis=1, inplace=True)

# %%
# Displaying the DataFrame after the modifications
df.head()
# Out:
#                          Company  Company Score  \
# 0                       ViewSoft            4.8
# 1                        Workiva            4.3
# 2     Garmin International, Inc.            3.9
# 3                       Snapchat            3.5
# 4  Vitesco Technologies Group AG            3.1
#
#                                            Job Title         Location  \
# 0                                  Software Engineer     Manassas, VA
# 1                          Software Support Engineer           Remote
# 2                               C# Software Engineer         Cary, NC
# 3  Software Engineer, Fullstack, 1+ Years of Expe...  Los Angeles, CA
# 4                                  Software Engineer       Seguin, TX
#
#    Min_Salary  Max_Salary
# 0       68000       94000
# 1       61000      104000
# 2       95000      118000
# 3       97000      145000
# 4       85000      108000

# %%
# Removing outlier
df = df.loc[df['Min_Salary'] > 10000]

# %%
# Displaying the DataFrame after the Removing outlier
df.describe()
# Out:
#        Company Score     Min_Salary     Max_Salary
# count     728.000000     728.000000     728.000000
# mean        3.895330  104770.604396  155619.505495
# std         0.526968   36866.103892   59750.646495
# min         1.000000   37000.000000   55000.000000
# 25%         3.600000   80000.000000  117000.000000
# 50%         3.900000   96000.000000  140000.000000
# 75%         4.200000  121250.000000  180000.000000
# max         5.000000  343000.000000  637000.000000

# %%
# Supondo que você tenha um DataFrame chamado df com as colunas 'Company', 'Job Title', 'Location'
df = pd.get_dummies(df, columns=['Company', 'Job Title', 'Location'])

# %%
df.head()
# Out:
#    Company Score  Min_Salary  Max_Salary  Company_3 Reasons Consulting  \
# 0            4.8       68000       94000                         False
# 1            4.3       61000      104000                         False
# 2            3.9       95000      118000                         False
# 3            3.5       97000      145000                         False
# 4            3.1       85000      108000                         False
#
#    Company_360care  Company_3R Info  Company_7-Eleven, Inc.  \
# 0            False            False                   False
# 1            False            False                   False
# 2            False            False                   False
# 3            False            False                   False
# 4            False            False                   False
#
#    Company_9th networks Inc  Company_AB2 Consulting, Inc.  \
# 0                     False                         False
# 1                     False                         False
# 2                     False                         False
# 3                     False                         False
# 4                     False                         False
#
#    Company_ACI Worldwide  ...  Location_Waterford, CT  Location_West Bend, WI  \
# 0                  False  ...                   False                   False
# 1                  False  ...                   False                   False
# 2                  False  ...                   False                   False
# 3                  False  ...                   False                   False
# 4                  False  ...                   False                   False
#
#    Location_Westlake Village, CA  Location_Westlake, TX  \
# 0                          False                  False
# 1                          False                  False
# 2                          False                  False
# 3                          False                  False
# 4                          False                  False
#
#    Location_White Plains, NY  Location_Whitehall Township  \
# 0                      False                        False
# 1                      False                        False
# 2                      False                        False
# 3                      False                        False
# 4                      False                        False
#
#    Location_Whitehouse Station, NJ  Location_Wilmington, DE  \
# 0                            False                    False
# 1                            False                    False
# 2                            False                    False
# 3                            False                    False
# 4                            False                    False
#
#    Location_Wilton Woods, VA  Location_Woonsocket, RI
# 0                      False                    False
# 1                      False                    False
# 2                      False                    False
# 3                      False                    False
# 4                      False                    False
#
# [5 rows x 1307 columns]

# %%
# Separando os dados
x = df.drop(['Min_Salary', 'Max_Salary'], axis = 1) # Removed extra brackets
y = df[['Min_Salary', 'Max_Salary']]

# Separe os dados de Treino e Teste
x_train, x_test, y_train, y_test = train_test_split(x, y)

# %%
# Criando um Objeto de Regressão Linear
lr = LinearRegression()

# Treine o Modelo
lr.fit(x_train, y_train)

# Avaliando o modelo
y_pred = lr.predict(x_test)

# %%
# Calcule o score do modelo
r_sq = lr.score(x, y)
print('Linear Regression (R²):', r_sq)
# Out:
# Linear Regression (R²): 0.6764837907150589

# %%
# Criando um objeto de Random Forest Regressor
rf = RandomForestRegressor(n_estimators=100, random_state=42)

# Treinando o modelo
rf.fit(x_train, y_train)

# Avaliando o modelo
y_pred = rf.predict(x_test)

# %%
# Calcule o score do modelo
r_sq = rf.score(x, y)
print('Random Forest Regressor (R²):', r_sq)
# Out:
# Random Forest Regressor (R²): 0.6085750125250596
